# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import citypy
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
size = 2000
lats = np.random.uniform(low=-90.000, high=90.000, size=size)
lngs = np.random.uniform(low=-180.000, high=180.000, size=size)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # get weather description
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | olga
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 1 | isiro
# Processing Record 5 of Set 1 | klaksvik
# Processing Record 6 of Set 1 | tiksi
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | talnakh
# Processing Record 9 of Set 1 | airai
# Processing Record 10 of Set 1 | namibe
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | fort nelson
# Processing Record 13 of Set 1 | dikson
# Processing Record 14 of Set 1 | yizheng
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | chokurdakh
# Processing Record 17 of Set 1 | cayhagan
# Processing Record 18 of Set 1 | ahipara
# Processing Record 19 of Set 1 | hasaki
# Processing Record 20 of Set 1 | rio claro
# Processing Record 21 of Set 1 | zhob
# Processing Record 22 of Set 1 | fortuna
# Processing Record 23 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 1 | kizilskoye
# Processing Record 25 of Set 1 | norman wells
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | puerto madryn
# Processing Record 29 of Set 1 | wahran
# City not found. Skipping...
# Processing Record 30 of Set 1 | anadyr
# Processing Record 31 of Set 1 | svetlogorsk
# Processing Record 32 of Set 1 | lazaro cardenas
# Processing Record 33 of Set 1 | pendleton
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | dhidhdhoo
# Processing Record 36 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 1 | neuenhof
# Processing Record 38 of Set 1 | requena
# Processing Record 39 of Set 1 | geraldton
# Processing Record 40 of Set 1 | georgetown
# Processing Record 41 of Set 1 | longlac
# City not found. Skipping...
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | zyryanka
# Processing Record 44 of Set 1 | san quintin
# Processing Record 45 of Set 1 | vyazemskiy
# Processing Record 46 of Set 1 | schenectady
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | cabo san lucas
# Processing Record 50 of Set 1 | padang
# Processing Record 1 of Set 2 | lavrentiya
# Processing Record 2 of Set 2 | uruburetama
# Processing Record 3 of Set 2 | clyde river
# Processing Record 4 of Set 2 | kavaratti
# Processing Record 5 of Set 2 | meulaboh
# Processing Record 6 of Set 2 | sorland
# Processing Record 7 of Set 2 | colac
# Processing Record 8 of Set 2 | poso
# Processing Record 9 of Set 2 | hilo
# Processing Record 10 of Set 2 | qaanaaq
# Processing Record 11 of Set 2 | calumet city
# Processing Record 12 of Set 2 | tabou
# Processing Record 13 of Set 2 | vardo
# Processing Record 14 of Set 2 | husavik
# Processing Record 15 of Set 2 | kenora
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | sumbawa
# City not found. Skipping...
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | bud
# Processing Record 20 of Set 2 | akhtanizovskaya
# Processing Record 21 of Set 2 | nyurba
# Processing Record 22 of Set 2 | corinto
# Processing Record 23 of Set 2 | banda aceh
# Processing Record 24 of Set 2 | kaitangata
# Processing Record 25 of Set 2 | ribeira grande
# Processing Record 26 of Set 2 | yellowknife
# Processing Record 27 of Set 2 | ancud
# Processing Record 28 of Set 2 | yinchuan
# Processing Record 29 of Set 2 | katsiveli
# City not found. Skipping...
# Processing Record 30 of Set 2 | nouadhibou
# Processing Record 31 of Set 2 | tuktoyaktuk
# Processing Record 32 of Set 2 | coquimbo
# Processing Record 33 of Set 2 | tasiilaq
# Processing Record 34 of Set 2 | bonnyville
# Processing Record 35 of Set 2 | jamestown
# Processing Record 36 of Set 2 | parras
# City not found. Skipping...
# Processing Record 37 of Set 2 | glamoc
# Processing Record 38 of Set 2 | atar
# Processing Record 39 of Set 2 | salalah
# Processing Record 40 of Set 2 | saldanha
# Processing Record 41 of Set 2 | korla
# Processing Record 42 of Set 2 | buariki
# City not found. Skipping...
# Processing Record 43 of Set 2 | sri aman
# Processing Record 44 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 2 | ambon
# Processing Record 46 of Set 2 | biltine
# Processing Record 47 of Set 2 | samana
# Processing Record 48 of Set 2 | avarua
# Processing Record 49 of Set 2 | svirstroy
# Processing Record 50 of Set 2 | los llanos de aridane
# Processing Record 1 of Set 3 | hobart
# Processing Record 2 of Set 3 | haines junction
# Processing Record 3 of Set 3 | barrow
# Processing Record 4 of Set 3 | yerbogachen
# Processing Record 5 of Set 3 | ciucurova
# Processing Record 6 of Set 3 | bilibino
# Processing Record 7 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 3 | longyearbyen
# Processing Record 9 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 10 of Set 3 | salto del guaira
# Processing Record 11 of Set 3 | dzilam gonzalez
# Processing Record 12 of Set 3 | egvekinot
# Processing Record 13 of Set 3 | chapais
# Processing Record 14 of Set 3 | pisco
# Processing Record 15 of Set 3 | new norfolk
# Processing Record 16 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 3 | grindavik
# Processing Record 18 of Set 3 | novosibirsk
# Processing Record 19 of Set 3 | provideniya
# Processing Record 20 of Set 3 | lae
# Processing Record 21 of Set 3 | pevek
# Processing Record 22 of Set 3 | kupang
# Processing Record 23 of Set 3 | mount gambier
# Processing Record 24 of Set 3 | vaini
# Processing Record 25 of Set 3 | east london
# Processing Record 26 of Set 3 | puerto ayora
# Processing Record 27 of Set 3 | atuona
# Processing Record 28 of Set 3 | sao filipe
# Processing Record 29 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 3 | abha
# Processing Record 31 of Set 3 | broken hill
# Processing Record 32 of Set 3 | hofn
# Processing Record 33 of Set 3 | grand gaube
# Processing Record 34 of Set 3 | les escoumins
# Processing Record 35 of Set 3 | saint george
# Processing Record 36 of Set 3 | mahebourg
# Processing Record 37 of Set 3 | paciran
# Processing Record 38 of Set 3 | khatanga
# Processing Record 39 of Set 3 | bluff
# Processing Record 40 of Set 3 | brae
# Processing Record 41 of Set 3 | amalapuram
# Processing Record 42 of Set 3 | sabang
# Processing Record 43 of Set 3 | nchelenge
# Processing Record 44 of Set 3 | tomatlan
# Processing Record 45 of Set 3 | torbay
# Processing Record 46 of Set 3 | ulaangom
# Processing Record 47 of Set 3 | warrington
# Processing Record 48 of Set 3 | saskylakh
# Processing Record 49 of Set 3 | monywa
# Processing Record 50 of Set 3 | lebu
# Processing Record 1 of Set 4 | broome
# Processing Record 2 of Set 4 | bandarbeyla
# Processing Record 3 of Set 4 | mataura
# Processing Record 4 of Set 4 | sistranda
# Processing Record 5 of Set 4 | bathsheba
# Processing Record 6 of Set 4 | narsaq
# Processing Record 7 of Set 4 | marawi
# Processing Record 8 of Set 4 | zhaotong
# Processing Record 9 of Set 4 | victoria
# Processing Record 10 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 11 of Set 4 | aksu
# Processing Record 12 of Set 4 | alexandria
# Processing Record 13 of Set 4 | whitehorse
# Processing Record 14 of Set 4 | mumbwa
# Processing Record 15 of Set 4 | devli
# Processing Record 16 of Set 4 | chongwe
# Processing Record 17 of Set 4 | aranos
# Processing Record 18 of Set 4 | marzuq
# Processing Record 19 of Set 4 | potgietersrus
# City not found. Skipping...
# Processing Record 20 of Set 4 | tiznit
# Processing Record 21 of Set 4 | bethel
# Processing Record 22 of Set 4 | westport
# Processing Record 23 of Set 4 | killin
# Processing Record 24 of Set 4 | cidreira
# Processing Record 25 of Set 4 | havelock
# Processing Record 26 of Set 4 | saint-louis
# Processing Record 27 of Set 4 | nanortalik
# Processing Record 28 of Set 4 | tungkang
# City not found. Skipping...
# Processing Record 29 of Set 4 | coracao de jesus
# Processing Record 30 of Set 4 | luganville
# Processing Record 31 of Set 4 | hithadhoo
# Processing Record 32 of Set 4 | dien bien
# City not found. Skipping...
# Processing Record 33 of Set 4 | sidi ali
# Processing Record 34 of Set 4 | tigil
# Processing Record 35 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 4 | kamaishi
# Processing Record 37 of Set 4 | caucaia
# Processing Record 38 of Set 4 | comodoro rivadavia
# Processing Record 39 of Set 4 | owo
# Processing Record 40 of Set 4 | hay river
# Processing Record 41 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 4 | lata
# Processing Record 43 of Set 4 | faya
# Processing Record 44 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 4 | pavlovsk
# Processing Record 46 of Set 4 | chodavaram
# Processing Record 47 of Set 4 | deniliquin
# Processing Record 48 of Set 4 | malpe
# Processing Record 49 of Set 4 | esperance
# Processing Record 50 of Set 4 | vostok
# Processing Record 1 of Set 5 | angoche
# Processing Record 2 of Set 5 | haifa
# Processing Record 3 of Set 5 | bambous virieux
# Processing Record 4 of Set 5 | high level
# Processing Record 5 of Set 5 | show low
# Processing Record 6 of Set 5 | conde
# Processing Record 7 of Set 5 | zabid
# Processing Record 8 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 5 | gerede
# Processing Record 10 of Set 5 | saint-philippe
# Processing Record 11 of Set 5 | gazanjyk
# Processing Record 12 of Set 5 | itarema
# Processing Record 13 of Set 5 | port elizabeth
# Processing Record 14 of Set 5 | naze
# Processing Record 15 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 16 of Set 5 | tommot
# Processing Record 17 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 18 of Set 5 | chagoda
# Processing Record 19 of Set 5 | general pico
# Processing Record 20 of Set 5 | bara
# Processing Record 21 of Set 5 | santa cruz del sur
# Processing Record 22 of Set 5 | patiya
# Processing Record 23 of Set 5 | sobolevo
# Processing Record 24 of Set 5 | jalu
# Processing Record 25 of Set 5 | axim
# Processing Record 26 of Set 5 | pedernales
# Processing Record 27 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 28 of Set 5 | fairbanks
# Processing Record 29 of Set 5 | kutum
# Processing Record 30 of Set 5 | sorong
# Processing Record 31 of Set 5 | trapani
# Processing Record 32 of Set 5 | cianorte
# Processing Record 33 of Set 5 | ghanzi
# Processing Record 34 of Set 5 | chuy
# Processing Record 35 of Set 5 | port blair
# Processing Record 36 of Set 5 | pemangkat
# Processing Record 37 of Set 5 | iqaluit
# Processing Record 38 of Set 5 | sanary-sur-mer
# Processing Record 39 of Set 5 | castro daire
# Processing Record 40 of Set 5 | imeni poliny osipenko
# Processing Record 41 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 5 | venado tuerto
# Processing Record 43 of Set 5 | mitsamiouli
# Processing Record 44 of Set 5 | albertville
# Processing Record 45 of Set 5 | upernavik
# Processing Record 46 of Set 5 | samarai
# Processing Record 47 of Set 5 | iquitos
# Processing Record 48 of Set 5 | shush
# Processing Record 49 of Set 5 | poum
# Processing Record 50 of Set 5 | hambantota
# Processing Record 1 of Set 6 | mayumba
# Processing Record 2 of Set 6 | severo-kurilsk
# Processing Record 3 of Set 6 | tuatapere
# Processing Record 4 of Set 6 | roebourne
# Processing Record 5 of Set 6 | jacareacanga
# Processing Record 6 of Set 6 | bumba
# Processing Record 7 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 8 of Set 6 | tazmalt
# Processing Record 9 of Set 6 | san jeronimo
# Processing Record 10 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 6 | alugan
# Processing Record 12 of Set 6 | carutapera
# Processing Record 13 of Set 6 | saint-joseph
# Processing Record 14 of Set 6 | mahanoro
# Processing Record 15 of Set 6 | uvarovo
# Processing Record 16 of Set 6 | rundu
# Processing Record 17 of Set 6 | iralaya
# Processing Record 18 of Set 6 | alekseyevsk
# Processing Record 19 of Set 6 | gander
# Processing Record 20 of Set 6 | butaritari
# Processing Record 21 of Set 6 | maldonado
# Processing Record 22 of Set 6 | olafsvik
# Processing Record 23 of Set 6 | lompoc
# Processing Record 24 of Set 6 | thompson
# Processing Record 25 of Set 6 | kloulklubed
# Processing Record 26 of Set 6 | omboue
# Processing Record 27 of Set 6 | camacha
# Processing Record 28 of Set 6 | cacule
# Processing Record 29 of Set 6 | altay
# Processing Record 30 of Set 6 | fene
# Processing Record 31 of Set 6 | rocha
# Processing Record 32 of Set 6 | umm kaddadah
# Processing Record 33 of Set 6 | tucuman
# Processing Record 34 of Set 6 | brownwood
# Processing Record 35 of Set 6 | pecos
# Processing Record 36 of Set 6 | cairns
# Processing Record 37 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 6 | bukachacha
# Processing Record 39 of Set 6 | uyo
# Processing Record 40 of Set 6 | kroya
# Processing Record 41 of Set 6 | secovce
# Processing Record 42 of Set 6 | lewistown
# Processing Record 43 of Set 6 | haapiti
# Processing Record 44 of Set 6 | fortaleza
# Processing Record 45 of Set 6 | tortoli
# Processing Record 46 of Set 6 | mar del plata
# Processing Record 47 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 6 | xuchang
# Processing Record 49 of Set 6 | buraydah
# Processing Record 50 of Set 6 | dargaville
# Processing Record 1 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 2 of Set 7 | pacifica
# Processing Record 3 of Set 7 | moose factory
# Processing Record 4 of Set 7 | rancho palos verdes
# Processing Record 5 of Set 7 | mount pleasant
# Processing Record 6 of Set 7 | netolice
# Processing Record 7 of Set 7 | aklavik
# Processing Record 8 of Set 7 | sale
# Processing Record 9 of Set 7 | vasilyevo
# Processing Record 10 of Set 7 | mangrol
# Processing Record 11 of Set 7 | atbasar
# Processing Record 12 of Set 7 | voyvozh
# Processing Record 13 of Set 7 | ponta do sol
# Processing Record 14 of Set 7 | port keats
# Processing Record 15 of Set 7 | alekseyevskaya
# Processing Record 16 of Set 7 | nikolskoye
# Processing Record 17 of Set 7 | manjeshwar
# Processing Record 18 of Set 7 | ugoofaaru
# Processing Record 19 of Set 7 | bahia honda
# Processing Record 20 of Set 7 | peleduy
# Processing Record 21 of Set 7 | souillac
# Processing Record 22 of Set 7 | bucerias
# Processing Record 23 of Set 7 | kernersville
# Processing Record 24 of Set 7 | leningradskiy
# Processing Record 25 of Set 7 | bayangol
# Processing Record 26 of Set 7 | achisay
# City not found. Skipping...
# Processing Record 27 of Set 7 | urengoy
# Processing Record 28 of Set 7 | nome
# Processing Record 29 of Set 7 | siderno
# Processing Record 30 of Set 7 | valdosta
# Processing Record 31 of Set 7 | yumen
# Processing Record 32 of Set 7 | sioux lookout
# Processing Record 33 of Set 7 | vanimo
# Processing Record 34 of Set 7 | pangnirtung
# Processing Record 35 of Set 7 | alta floresta
# Processing Record 36 of Set 7 | vitimskiy
# City not found. Skipping...
# Processing Record 37 of Set 7 | inhambane
# Processing Record 38 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 7 | ucluelet
# Processing Record 40 of Set 7 | iskar
# Processing Record 41 of Set 7 | natchitoches
# Processing Record 42 of Set 7 | lagos
# Processing Record 43 of Set 7 | te anau
# Processing Record 44 of Set 7 | sibolga
# Processing Record 45 of Set 7 | kavieng
# Processing Record 46 of Set 7 | saint-augustin
# Processing Record 47 of Set 7 | castro
# Processing Record 48 of Set 7 | arraial do cabo
# Processing Record 49 of Set 7 | port hedland
# Processing Record 50 of Set 7 | qorveh
# Processing Record 1 of Set 8 | warkworth
# Processing Record 2 of Set 8 | bengkulu
# Processing Record 3 of Set 8 | veraval
# Processing Record 4 of Set 8 | syamzha
# Processing Record 5 of Set 8 | marsh harbour
# Processing Record 6 of Set 8 | fresnillo
# Processing Record 7 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 8 | povenets
# Processing Record 9 of Set 8 | san patricio
# Processing Record 10 of Set 8 | sterling
# Processing Record 11 of Set 8 | puerto cabezas
# Processing Record 12 of Set 8 | touros
# Processing Record 13 of Set 8 | kruisfontein
# Processing Record 14 of Set 8 | kahului
# Processing Record 15 of Set 8 | asau
# Processing Record 16 of Set 8 | pala
# Processing Record 17 of Set 8 | bayan
# Processing Record 18 of Set 8 | mana
# Processing Record 19 of Set 8 | marathon
# Processing Record 20 of Set 8 | moron
# Processing Record 21 of Set 8 | san andres
# Processing Record 22 of Set 8 | beyneu
# Processing Record 23 of Set 8 | lagoa
# Processing Record 24 of Set 8 | bintulu
# Processing Record 25 of Set 8 | cali
# Processing Record 26 of Set 8 | keti bandar
# Processing Record 27 of Set 8 | richards bay
# Processing Record 28 of Set 8 | gushikawa
# Processing Record 29 of Set 8 | otane
# Processing Record 30 of Set 8 | gamba
# Processing Record 31 of Set 8 | lovozero
# Processing Record 32 of Set 8 | biak
# Processing Record 33 of Set 8 | necochea
# Processing Record 34 of Set 8 | puerto escondido
# Processing Record 35 of Set 8 | ca mau
# Processing Record 36 of Set 8 | bow island
# Processing Record 37 of Set 8 | caravelas
# Processing Record 38 of Set 8 | ayna
# Processing Record 39 of Set 8 | rabo de peixe
# Processing Record 40 of Set 8 | constitucion
# Processing Record 41 of Set 8 | turayf
# Processing Record 42 of Set 8 | vila velha
# Processing Record 43 of Set 8 | mogapinyana
# Processing Record 44 of Set 8 | faanui
# Processing Record 45 of Set 8 | fare
# Processing Record 46 of Set 8 | northam
# Processing Record 47 of Set 8 | fallon
# Processing Record 48 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 8 | qasigiannguit
# Processing Record 50 of Set 8 | sawakin
# Processing Record 1 of Set 9 | kimamba
# Processing Record 2 of Set 9 | benjamin aceval
# Processing Record 3 of Set 9 | flinders
# Processing Record 4 of Set 9 | vrangel
# Processing Record 5 of Set 9 | jacmel
# Processing Record 6 of Set 9 | gazni
# City not found. Skipping...
# Processing Record 7 of Set 9 | rio gallegos
# Processing Record 8 of Set 9 | halifax
# Processing Record 9 of Set 9 | lakatoro
# Processing Record 10 of Set 9 | victor harbor
# Processing Record 11 of Set 9 | honiara
# Processing Record 12 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 13 of Set 9 | sauga
# Processing Record 14 of Set 9 | lethem
# Processing Record 15 of Set 9 | ranong
# Processing Record 16 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 9 | senanga
# Processing Record 18 of Set 9 | wattegama
# Processing Record 19 of Set 9 | osa
# Processing Record 20 of Set 9 | concordia
# Processing Record 21 of Set 9 | loviisa
# Processing Record 22 of Set 9 | gabu
# Processing Record 23 of Set 9 | kpandae
# Processing Record 24 of Set 9 | coihaique
# Processing Record 25 of Set 9 | wanaka
# Processing Record 26 of Set 9 | moissala
# Processing Record 27 of Set 9 | luanda
# Processing Record 28 of Set 9 | alofi
# Processing Record 29 of Set 9 | khuzdar
# Processing Record 30 of Set 9 | govindgarh
# Processing Record 31 of Set 9 | estelle
# Processing Record 32 of Set 9 | ust-ishim
# Processing Record 33 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 34 of Set 9 | denpasar
# Processing Record 35 of Set 9 | ulladulla
# Processing Record 36 of Set 9 | tocopilla
# Processing Record 37 of Set 9 | kudahuvadhoo
# Processing Record 38 of Set 9 | beringovskiy
# Processing Record 39 of Set 9 | seymchan
# Processing Record 40 of Set 9 | ilulissat
# Processing Record 41 of Set 9 | taoudenni
# Processing Record 42 of Set 9 | zhongshu
# Processing Record 43 of Set 9 | vilyuysk
# Processing Record 44 of Set 9 | libertador general san martin
# Processing Record 45 of Set 9 | sur
# Processing Record 46 of Set 9 | calama
# Processing Record 47 of Set 9 | coahuayana
# Processing Record 48 of Set 9 | antofagasta
# Processing Record 49 of Set 9 | port lincoln
# Processing Record 50 of Set 9 | horodnytsya
# Processing Record 1 of Set 10 | libenge
# Processing Record 2 of Set 10 | kungurtug
# Processing Record 3 of Set 10 | yarada
# Processing Record 4 of Set 10 | lorengau
# Processing Record 5 of Set 10 | gravdal
# Processing Record 6 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 7 of Set 10 | breytovo
# Processing Record 8 of Set 10 | katsuura
# Processing Record 9 of Set 10 | batken
# Processing Record 10 of Set 10 | burns lake
# Processing Record 11 of Set 10 | komsomolskiy
# Processing Record 12 of Set 10 | dolgorukovo
# Processing Record 13 of Set 10 | luorong
# Processing Record 14 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 15 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 10 | bambanglipuro
# Processing Record 17 of Set 10 | makinsk
# Processing Record 18 of Set 10 | staryy nadym
# Processing Record 19 of Set 10 | hirara
# Processing Record 20 of Set 10 | port hawkesbury
# Processing Record 21 of Set 10 | berea
# Processing Record 22 of Set 10 | batagay
# Processing Record 23 of Set 10 | anqing
# Processing Record 24 of Set 10 | college
# Processing Record 25 of Set 10 | dryden
# Processing Record 26 of Set 10 | udachnyy
# Processing Record 27 of Set 10 | callaway
# Processing Record 28 of Set 10 | ganzhou
# Processing Record 29 of Set 10 | marrakesh
# Processing Record 30 of Set 10 | maceio
# Processing Record 31 of Set 10 | namatanai
# Processing Record 32 of Set 10 | filadelfia
# Processing Record 33 of Set 10 | harnosand
# Processing Record 34 of Set 10 | pandan
# Processing Record 35 of Set 10 | uttarkashi
# Processing Record 36 of Set 10 | neiafu
# Processing Record 37 of Set 10 | mandera
# Processing Record 38 of Set 10 | san policarpo
# Processing Record 39 of Set 10 | yar-sale
# Processing Record 40 of Set 10 | eseka
# Processing Record 41 of Set 10 | tome-acu
# City not found. Skipping...
# Processing Record 42 of Set 10 | khani
# Processing Record 43 of Set 10 | labuhan
# Processing Record 44 of Set 10 | waipawa
# Processing Record 45 of Set 10 | la ronge
# Processing Record 46 of Set 10 | gangotri
# City not found. Skipping...
# Processing Record 47 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 10 | paka
# Processing Record 49 of Set 10 | gadwal
# Processing Record 50 of Set 10 | abu kamal
# Processing Record 1 of Set 11 | tessalit
# Processing Record 2 of Set 11 | huaiyuan
# Processing Record 3 of Set 11 | carnarvon
# Processing Record 4 of Set 11 | tilichiki
# Processing Record 5 of Set 11 | hampden
# Processing Record 6 of Set 11 | yaring
# Processing Record 7 of Set 11 | padre bernardo
# Processing Record 8 of Set 11 | armeria
# Processing Record 9 of Set 11 | nichinan
# Processing Record 10 of Set 11 | mackay
# Processing Record 11 of Set 11 | sitka
# Processing Record 12 of Set 11 | awjilah
# Processing Record 13 of Set 11 | nargana
# Processing Record 14 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 15 of Set 11 | unye
# City not found. Skipping...
# Processing Record 16 of Set 11 | acajutla
# Processing Record 17 of Set 11 | cap malheureux
# Processing Record 18 of Set 11 | chunskiy
# Processing Record 19 of Set 11 | eucaliptus
# Processing Record 20 of Set 11 | san francisco
# Processing Record 21 of Set 11 | masterton
# Processing Record 22 of Set 11 | alora
# Processing Record 23 of Set 11 | auckland
# Processing Record 24 of Set 11 | pittsfield
# Processing Record 25 of Set 11 | shahreza
# Processing Record 26 of Set 11 | sisimiut
# Processing Record 27 of Set 11 | malinovoye ozero
# Processing Record 28 of Set 11 | golpayegan
# Processing Record 29 of Set 11 | lucapa
# Processing Record 30 of Set 11 | maraa
# Processing Record 31 of Set 11 | matagami
# Processing Record 32 of Set 11 | dzhebariki-khaya
# Processing Record 33 of Set 11 | kirakira
# Processing Record 34 of Set 11 | keetmanshoop
# Processing Record 35 of Set 11 | kysyl-syr
# Processing Record 36 of Set 11 | qaqortoq
# Processing Record 37 of Set 11 | chernyshevskiy
# Processing Record 38 of Set 11 | raiganj
# Processing Record 39 of Set 11 | portland
# Processing Record 40 of Set 11 | saint-pierre
# Processing Record 41 of Set 11 | maltahohe
# Processing Record 42 of Set 11 | paredon
# Processing Record 43 of Set 11 | honningsvag
# Processing Record 44 of Set 11 | oktyabrskiy
# Processing Record 45 of Set 11 | chulman
# Processing Record 46 of Set 11 | samoded
# Processing Record 47 of Set 11 | powell
# Processing Record 48 of Set 11 | ryde
# Processing Record 49 of Set 11 | thunder bay
# Processing Record 50 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 12 | kharabali
# Processing Record 3 of Set 12 | port macquarie
# Processing Record 4 of Set 12 | vila franca do campo
# Processing Record 5 of Set 12 | ushibuka
# Processing Record 6 of Set 12 | shelburne
# Processing Record 7 of Set 12 | bose
# Processing Record 8 of Set 12 | yarmouth
# Processing Record 9 of Set 12 | burica
# City not found. Skipping...
# Processing Record 10 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 12 | shiraz
# Processing Record 12 of Set 12 | hanyang
# Processing Record 13 of Set 12 | asayita
# City not found. Skipping...
# Processing Record 14 of Set 12 | newport
# Processing Record 15 of Set 12 | chubbuck
# Processing Record 16 of Set 12 | nago
# Processing Record 17 of Set 12 | miranorte
# City not found. Skipping...
# Processing Record 18 of Set 12 | les cayes
# Processing Record 19 of Set 12 | jardim
# Processing Record 20 of Set 12 | cananea
# Processing Record 21 of Set 12 | port augusta
# Processing Record 22 of Set 12 | tondon
# Processing Record 23 of Set 12 | tura
# Processing Record 24 of Set 12 | edinburg
# Processing Record 25 of Set 12 | isla vista
# Processing Record 26 of Set 12 | ardatov
# Processing Record 27 of Set 12 | eston
# Processing Record 28 of Set 12 | okhotsk
# Processing Record 29 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 30 of Set 12 | cherskiy
# Processing Record 31 of Set 12 | blagoyevo
# Processing Record 32 of Set 12 | dunedin
# Processing Record 33 of Set 12 | yamada
# Processing Record 34 of Set 12 | adrar
# Processing Record 35 of Set 12 | opuwo
# Processing Record 36 of Set 12 | preobrazheniye
# Processing Record 37 of Set 12 | aiken
# Processing Record 38 of Set 12 | prince rupert
# Processing Record 39 of Set 12 | ardahan
# Processing Record 40 of Set 12 | hobyo
# Processing Record 41 of Set 12 | vidim
# Processing Record 42 of Set 12 | tual
# Processing Record 43 of Set 12 | santa cruz
# Processing Record 44 of Set 12 | caceres
# Processing Record 45 of Set 12 | andros town
# Processing Record 46 of Set 12 | afmadu
# City not found. Skipping...
# Processing Record 47 of Set 12 | chicama
# Processing Record 48 of Set 12 | bereznik
# Processing Record 49 of Set 12 | maloshuyka
# City not found. Skipping...
# Processing Record 50 of Set 12 | taburi
# City not found. Skipping...
# Processing Record 1 of Set 13 | greymouth
# Processing Record 2 of Set 13 | manuk mangkaw
# Processing Record 3 of Set 13 | itanhaem
# Processing Record 4 of Set 13 | murray bridge
# Processing Record 5 of Set 13 | najran
# Processing Record 6 of Set 13 | maniitsoq
# Processing Record 7 of Set 13 | owando
# Processing Record 8 of Set 13 | mubi
# Processing Record 9 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 10 of Set 13 | yaan
# Processing Record 11 of Set 13 | alice springs
# Processing Record 12 of Set 13 | araouane
# Processing Record 13 of Set 13 | quatre cocos
# Processing Record 14 of Set 13 | effium
# Processing Record 15 of Set 13 | kisangani
# Processing Record 16 of Set 13 | kwinana
# Processing Record 17 of Set 13 | lydenburg
# Processing Record 18 of Set 13 | caninde
# Processing Record 19 of Set 13 | santa vitoria do palmar
# Processing Record 20 of Set 13 | calvinia
# Processing Record 21 of Set 13 | andilamena
# Processing Record 22 of Set 13 | avera
# Processing Record 23 of Set 13 | chengde
# Processing Record 24 of Set 13 | flin flon
# Processing Record 25 of Set 13 | koungou
# Processing Record 26 of Set 13 | muros
# Processing Record 27 of Set 13 | deputatskiy
# Processing Record 28 of Set 13 | padilla
# Processing Record 29 of Set 13 | inuvik
# Processing Record 30 of Set 13 | minsk
# Processing Record 31 of Set 13 | leshukonskoye
# Processing Record 32 of Set 13 | kinango
# Processing Record 33 of Set 13 | havre-saint-pierre
# Processing Record 34 of Set 13 | viedma
# Processing Record 35 of Set 13 | maumere
# Processing Record 36 of Set 13 | rock sound
# Processing Record 37 of Set 13 | dehloran
# Processing Record 38 of Set 13 | kismayo
# Processing Record 39 of Set 13 | tremedal
# Processing Record 40 of Set 13 | katherine
# Processing Record 41 of Set 13 | sabha
# Processing Record 42 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 43 of Set 13 | moree
# Processing Record 44 of Set 13 | elizabeth city
# Processing Record 45 of Set 13 | kochkurovo
# Processing Record 46 of Set 13 | sydney mines
# Processing Record 47 of Set 13 | neuquen
# Processing Record 48 of Set 13 | margate
# Processing Record 49 of Set 13 | ambunti
# Processing Record 50 of Set 13 | urucara
# Processing Record 1 of Set 14 | sinnamary
# Processing Record 2 of Set 14 | kuching
# Processing Record 3 of Set 14 | nemuro
# Processing Record 4 of Set 14 | gillette
# Processing Record 5 of Set 14 | hamilton
# Processing Record 6 of Set 14 | emerald
# Processing Record 7 of Set 14 | ust-charyshskaya pristan
# Processing Record 8 of Set 14 | sug-aksy
# City not found. Skipping...
# Processing Record 9 of Set 14 | zhigansk
# Processing Record 10 of Set 14 | nizhniy kuranakh
# Processing Record 11 of Set 14 | karratha
# Processing Record 12 of Set 14 | walvis bay
# Processing Record 13 of Set 14 | harper
# Processing Record 14 of Set 14 | eisenach
# Processing Record 15 of Set 14 | itupiranga
# Processing Record 16 of Set 14 | porto novo
# Processing Record 17 of Set 14 | ixtapa
# Processing Record 18 of Set 14 | melfi
# Processing Record 19 of Set 14 | nantucket
# Processing Record 20 of Set 14 | eureka
# Processing Record 21 of Set 14 | coari
# Processing Record 22 of Set 14 | la palma
# Processing Record 23 of Set 14 | tautira
# Processing Record 24 of Set 14 | polyarnyy
# Processing Record 25 of Set 14 | lahat
# Processing Record 26 of Set 14 | dalbandin
# Processing Record 27 of Set 14 | targoviste
# Processing Record 28 of Set 14 | griffith
# Processing Record 29 of Set 14 | mehamn
# Processing Record 30 of Set 14 | manzil jamil
# City not found. Skipping...
# Processing Record 31 of Set 14 | hit
# Processing Record 32 of Set 14 | usvyaty
# Processing Record 33 of Set 14 | puerto del rosario
# Processing Record 34 of Set 14 | grand-santi
# Processing Record 35 of Set 14 | bac ninh
# Processing Record 36 of Set 14 | panzhihua
# Processing Record 37 of Set 14 | tromso
# Processing Record 38 of Set 14 | marshall
# Processing Record 39 of Set 14 | den helder
# Processing Record 40 of Set 14 | bocana de paiwas
# Processing Record 41 of Set 14 | kozmodemyansk
# Processing Record 42 of Set 14 | conkal
# Processing Record 43 of Set 14 | the pas
# Processing Record 44 of Set 14 | seybaplaya
# Processing Record 45 of Set 14 | khorixas
# Processing Record 46 of Set 14 | grand forks
# Processing Record 47 of Set 14 | blackfoot
# Processing Record 48 of Set 14 | guerrero negro
# Processing Record 49 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 14 | mount isa
# Processing Record 1 of Set 15 | ajdabiya
# Processing Record 2 of Set 15 | rio grande city
# Processing Record 3 of Set 15 | tara
# Processing Record 4 of Set 15 | loughrea
# Processing Record 5 of Set 15 | ciudad bolivar
# Processing Record 6 of Set 15 | kampong thum
# Processing Record 7 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 8 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 9 of Set 15 | beira
# Processing Record 10 of Set 15 | meihekou
# Processing Record 11 of Set 15 | aksha
# Processing Record 12 of Set 15 | natal
# Processing Record 13 of Set 15 | verkhnevilyuysk
# Processing Record 14 of Set 15 | anyama
# Processing Record 15 of Set 15 | half moon bay
# Processing Record 16 of Set 15 | abastumani
# Processing Record 17 of Set 15 | east chicago
# Processing Record 18 of Set 15 | port moresby
# Processing Record 19 of Set 15 | conceicao do araguaia
# Processing Record 20 of Set 15 | pemba
# Processing Record 21 of Set 15 | tezu
# Processing Record 22 of Set 15 | chilca
# Processing Record 23 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 15 | harer
# Processing Record 25 of Set 15 | sal rei
# Processing Record 26 of Set 15 | dobson
# Processing Record 27 of Set 15 | piedecuesta
# Processing Record 28 of Set 15 | isangel
# Processing Record 29 of Set 15 | kiama
# Processing Record 30 of Set 15 | letlhakane
# Processing Record 31 of Set 15 | umba
# Processing Record 32 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 33 of Set 15 | sedan
# Processing Record 34 of Set 15 | woodstock
# Processing Record 35 of Set 15 | gboko
# Processing Record 36 of Set 15 | ketchikan
# Processing Record 37 of Set 15 | louis trichardt
# Processing Record 38 of Set 15 | laguna
# Processing Record 39 of Set 15 | goiania
# Processing Record 40 of Set 15 | priiskovyy
# Processing Record 41 of Set 15 | oranjemund
# Processing Record 42 of Set 15 | sakakah
# Processing Record 43 of Set 15 | cayenne
# Processing Record 44 of Set 15 | codrington
# Processing Record 45 of Set 15 | bonthe
# Processing Record 46 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 47 of Set 15 | idrinskoye
# Processing Record 48 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 49 of Set 15 | mattersburg
# Processing Record 50 of Set 15 | miri
# Processing Record 1 of Set 16 | umm durman
# City not found. Skipping...
# Processing Record 2 of Set 16 | drugovo
# Processing Record 3 of Set 16 | tabas
# Processing Record 4 of Set 16 | alghero
# Processing Record 5 of Set 16 | cheyenne
# Processing Record 6 of Set 16 | sharkan
# Processing Record 7 of Set 16 | verkhnyaya inta
# Processing Record 8 of Set 16 | bajo baudo
# City not found. Skipping...
# Processing Record 9 of Set 16 | pundaguitan
# Processing Record 10 of Set 16 | wegorzewo
# Processing Record 11 of Set 16 | burgeo
# Processing Record 12 of Set 16 | chingirlau
# Processing Record 13 of Set 16 | aflu
# City not found. Skipping...
# Processing Record 14 of Set 16 | kadykchan
# City not found. Skipping...
# Processing Record 15 of Set 16 | hami
# Processing Record 16 of Set 16 | erseke
# Processing Record 17 of Set 16 | dumai
# Processing Record 18 of Set 16 | entre rios
# Processing Record 19 of Set 16 | belmonte
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 0        Olga      RU  2022-06-05 02:00:51  43.7444  135.2892     52.09
# 1  Bredasdorp      ZA  2022-06-05 02:00:52 -34.5322   20.0403     57.88
# 2       Isiro      CD  2022-06-05 02:00:52   2.7739   27.6160     65.93
# 3    Klaksvik      FO  2022-06-05 02:00:53  62.2266   -6.5890     49.12
# 4       Tiksi      RU  2022-06-05 02:00:53  71.6872  128.8694     54.73
# 5     Rikitea      PF  2022-06-05 01:55:18 -23.1203 -134.9692     74.53
# 6     Talnakh      RU  2022-06-05 02:00:53  69.4865   88.3972     27.21
# 7       Airai      TL  2022-06-05 02:00:54  -8.9266  125.4092     72.82
# 8      Namibe      AO  2022-06-05 02:00:54 -15.1961   12.1522     75.54
# 9      Albany      US  2022-06-05 01:55:19  42.6001  -73.9662     60.17
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        62         100       10.58     overcast clouds
# 1        71         100        9.78     overcast clouds
# 2        96          50        1.16    scattered clouds
# 3        92         100        5.75     overcast clouds
# 4        74         100       16.53     overcast clouds
# 5        68         100        8.12     overcast clouds
# 6        63           9       16.93           clear sky
# 7        60          73        2.10       broken clouds
# 8        36           1       13.58           clear sky
# 9        47           0        4.00           clear sky

# %%
# Reorder columns and select columns we want for analysis
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Olga      RU  43.7444  135.2892     52.09        62         100
# 1  Bredasdorp      ZA -34.5322   20.0403     57.88        71         100
# 2       Isiro      CD   2.7739   27.6160     65.93        96          50
# 3    Klaksvik      FO  62.2266   -6.5890     49.12        92         100
# 4       Tiksi      RU  71.6872  128.8694     54.73        74         100
# 5     Rikitea      PF -23.1203 -134.9692     74.53        68         100
# 6     Talnakh      RU  69.4865   88.3972     27.21        63           9
# 7       Airai      TL  -8.9266  125.4092     72.82        60          73
# 8      Namibe      AO -15.1961   12.1522     75.54        36           1
# 9      Albany      US  42.6001  -73.9662     60.17        47           0
#
#    Wind Speed Current Description
# 0       10.58     overcast clouds
# 1        9.78     overcast clouds
# 2        1.16    scattered clouds
# 3        5.75     overcast clouds
# 4       16.53     overcast clouds
# 5        8.12     overcast clouds
# 6       16.93           clear sky
# 7        2.10       broken clouds
# 8       13.58           clear sky
# 9        4.00           clear sky

# %%
# Create the WeatherPy_Database.csv file
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into the CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
